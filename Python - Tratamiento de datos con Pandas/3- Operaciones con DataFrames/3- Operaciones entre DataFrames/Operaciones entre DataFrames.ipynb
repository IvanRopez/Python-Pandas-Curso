# %%
import numpy as np
import pandas as pd
from pathlib import Path
path = Path('../datos')
house = pd.read_csv(path / 'house.csv')
house.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %%
df1 = house.iloc[0:10]
df1.shape
# Out:
# (10, 18)

# %%
df2 = house.iloc[-10:]
df2.shape
# Out:
# (10, 18)

# %%
dft1 = pd.concat([df1, df2], axis = 0)
dft1.shape
# Out:
# (20, 18)

# %%
dft2 = pd.concat([df1, df2], axis = 1)
dft2.shape
# Out:
# (20, 36)

# %%
df = pd.concat([df1, df2], axis = 0, keys = ['head', 'tail']) #Crea un multiindex
df
# Out:
#                           date         price  bedrooms  bathrooms  \
# head 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50
#      1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50
#      2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00
#      3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25
#      4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50
#      5     2014-05-02 00:00:00  4.900000e+05       2.0       1.00
#      6     2014-05-02 00:00:00  3.350000e+05       2.0       2.00
#      7     2014-05-02 00:00:00  4.820000e+05       4.0       2.50
#      8     2014-05-02 00:00:00  4.525000e+05       3.0       2.50
#      9     2014-05-02 00:00:00  6.400000e+05       4.0       2.00
# tail 4590  2014-07-08 00:00:00  3.806806e+05       4.0       2.50
#      4591  2014-07-08 00:00:00  3.961667e+05       3.0       1.75
#      4592  2014-07-08 00:00:00  2.529800e+05       4.0       2.50
# ...

# %%
df.loc['tail']
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4590  2014-07-08 00:00:00  380680.555556       4.0       2.50         2620
# 4591  2014-07-08 00:00:00  396166.666667       3.0       1.75         1880
# 4592  2014-07-08 00:00:00  252980.000000       4.0       2.50         2530
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# 4594  2014-07-09 00:00:00  210614.285714       3.0       2.50         1610
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4590      8331     2.0           0     0          3        2620
# ...

# %%
df1.append(df2, ignore_index = True) #Añade al final e ignora indice
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21132\1596917442.py in ?()
# ----> 1 df1.append(df2, ignore_index = True) #Añade al final e ignora indice
#
# ~\anaconda3\envs\dataScience\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df1 = house.loc[0:10, ['price', 'bedrooms']]
df1
# Out:
#         price  bedrooms
# 0    313000.0       3.0
# 1   2384000.0       5.0
# 2    342000.0       3.0
# 3    420000.0       3.0
# 4    550000.0       4.0
# 5    490000.0       2.0
# 6    335000.0       2.0
# 7    482000.0       4.0
# 8    452500.0       3.0
# 9    640000.0       4.0
# 10   463000.0       3.0

# %%
df2 = house.loc[0:10, ['city', 'statezip', 'country']]
df2
# Out:
#                 city  statezip country
# 0          Shoreline  WA 98133     USA
# 1            Seattle  WA 98119     USA
# 2               Kent  WA 98042     USA
# 3           Bellevue  WA 98008     USA
# 4            Redmond  WA 98052     USA
# 5            Seattle  WA 98115     USA
# 6            Redmond  WA 98052     USA
# 7       Maple Valley  WA 98038     USA
# 8         North Bend  WA 98045     USA
# 9            Seattle  WA 98115     USA
# 10  Lake Forest Park  WA 98155     USA

# %%
df = pd.concat([df1, df2], axis = 1) #Con axis 1 se pega a nivel columna
df
# Out:
#         price  bedrooms              city  statezip country
# 0    313000.0       3.0         Shoreline  WA 98133     USA
# 1   2384000.0       5.0           Seattle  WA 98119     USA
# 2    342000.0       3.0              Kent  WA 98042     USA
# 3    420000.0       3.0          Bellevue  WA 98008     USA
# 4    550000.0       4.0           Redmond  WA 98052     USA
# 5    490000.0       2.0           Seattle  WA 98115     USA
# 6    335000.0       2.0           Redmond  WA 98052     USA
# 7    482000.0       4.0      Maple Valley  WA 98038     USA
# 8    452500.0       3.0        North Bend  WA 98045     USA
# 9    640000.0       4.0           Seattle  WA 98115     USA
# 10   463000.0       3.0  Lake Forest Park  WA 98155     USA

# %%
df1 = house.loc[0:10, ['city', 'price', 'bedrooms']]
df1
# Out:
#                 city      price  bedrooms
# 0          Shoreline   313000.0       3.0
# 1            Seattle  2384000.0       5.0
# 2               Kent   342000.0       3.0
# 3           Bellevue   420000.0       3.0
# 4            Redmond   550000.0       4.0
# 5            Seattle   490000.0       2.0
# 6            Redmond   335000.0       2.0
# 7       Maple Valley   482000.0       4.0
# 8         North Bend   452500.0       3.0
# 9            Seattle   640000.0       4.0
# 10  Lake Forest Park   463000.0       3.0

# %%
df2 = house.loc[0:10, ['city', 'statezip', 'country']]
df2
# Out:
#                 city  statezip country
# 0          Shoreline  WA 98133     USA
# 1            Seattle  WA 98119     USA
# 2               Kent  WA 98042     USA
# 3           Bellevue  WA 98008     USA
# 4            Redmond  WA 98052     USA
# 5            Seattle  WA 98115     USA
# 6            Redmond  WA 98052     USA
# 7       Maple Valley  WA 98038     USA
# 8         North Bend  WA 98045     USA
# 9            Seattle  WA 98115     USA
# 10  Lake Forest Park  WA 98155     USA

# %%
df = df1.merge(df2, how='left', left_on='city', right_on='city')
df.head(2)
# Out:
#         city      price  bedrooms  statezip country
# 0  Shoreline   313000.0       3.0  WA 98133     USA
# 1    Seattle  2384000.0       5.0  WA 98119     USA

# %%
df = df1.join(df2, lsuffix='_x', rsuffix='_y') #Une por índice y llama x e y a la misma columna
df
# Out:
#               city_x      price  bedrooms            city_y  statezip country
# 0          Shoreline   313000.0       3.0         Shoreline  WA 98133     USA
# 1            Seattle  2384000.0       5.0           Seattle  WA 98119     USA
# 2               Kent   342000.0       3.0              Kent  WA 98042     USA
# 3           Bellevue   420000.0       3.0          Bellevue  WA 98008     USA
# 4            Redmond   550000.0       4.0           Redmond  WA 98052     USA
# 5            Seattle   490000.0       2.0           Seattle  WA 98115     USA
# 6            Redmond   335000.0       2.0           Redmond  WA 98052     USA
# 7       Maple Valley   482000.0       4.0      Maple Valley  WA 98038     USA
# 8         North Bend   452500.0       3.0        North Bend  WA 98045     USA
# 9            Seattle   640000.0       4.0           Seattle  WA 98115     USA
# 10  Lake Forest Park   463000.0       3.0  Lake Forest Park  WA 98155     USA
