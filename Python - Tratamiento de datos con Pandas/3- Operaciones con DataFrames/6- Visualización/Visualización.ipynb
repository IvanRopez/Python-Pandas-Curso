# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from pathlib import Path
path = Path('../datos')
house = pd.read_csv(path / 'house.csv')
house.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %%
date = house.drop_duplicates(subset=['date'], keep='first') #Date única sin duplicados
date.shape
# Out:
# (70, 18)

# %%
date.head()
# Out:
#                     date     price  bedrooms  bathrooms  sqft_living  \
# 0    2014-05-02 00:00:00  313000.0       3.0       1.50         1340
# 64   2014-05-03 00:00:00  625000.0       4.0       2.75         2920
# 68   2014-05-04 00:00:00  775000.0       2.0       2.50         2680
# 73   2014-05-05 00:00:00  560000.0       3.0       2.50         1900
# 151  2014-05-06 00:00:00  397000.0       4.0       2.00         1440
#
#      sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 0        7912     1.5           0     0          3        1340              0
# 64       6605     2.0           0     0          3        2920              0
# 68       7392     1.0           0     0          3        2680              0
# 73       8744     2.0           0     0          3        1900              0
# 151      7680     1.0           0     0          3        1200            240
#
#      yr_built  yr_renovated                street       city  statezip country
# ...

# %%
date.index = date['date'] #Date como índice

# %%
date = date.drop(labels = ['date'], axis=1) #Borrar la columna date porque la tenemos como índice
date.head()
# Out:
#                         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00  313000.0       3.0       1.50         1340      7912
# 2014-05-03 00:00:00  625000.0       4.0       2.75         2920      6605
# 2014-05-04 00:00:00  775000.0       2.0       2.50         2680      7392
# 2014-05-05 00:00:00  560000.0       3.0       2.50         1900      8744
# 2014-05-06 00:00:00  397000.0       4.0       2.00         1440      7680
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-03 00:00:00     2.0           0     0          3        2920
# 2014-05-04 00:00:00     1.0           0     0          3        2680
# 2014-05-05 00:00:00     2.0           0     0          3        1900
# 2014-05-06 00:00:00     1.0           0     0          3        1200
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
### Gráfico de líneas

# %%
date[['price']].plot(figsize = (20,8))
# Out:
# <Axes: xlabel='date'>

# %%
### Gráfico de barras

# %%
date[['bathrooms']].plot(kind='bar', figsize=(20,8))
# Out:
# <Axes: xlabel='date'>

# %%
date[['bathrooms', 'floors']].plot(kind='bar', figsize=(20,8)) #Varias columnas
# Out:
# <Axes: xlabel='date'>

# %%
### Gráfico de puntos

# %%
date.plot(kind='scatter', x='yr_built', y='sqft_above', figsize=(10,8))
# Out:
# <Axes: xlabel='yr_built', ylabel='sqft_above'>

# %%
### Gráfico de cajas

# %%
date[['bathrooms', 'floors']].plot(kind='box', figsize=(10,8))
# Out:
# <Axes: >

# %%
### Gráfico de tarta

# %%
date['condition'].value_counts(normalize=True).plot(kind='pie', figsize=(10,8))
# Out:
# <Axes: ylabel='proportion'>

# %%
date['condition'].value_counts(normalize=True).plot(kind='pie', figsize=(10,8), legend=True)
# Out:
# <Axes: ylabel='proportion'>
