# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
data_path = Path('../datos')

# %%
dataset = pd.read_csv(filepath_or_buffer = data_path / 'Ejercicio.csv', sep = ',')
dataset
# Out:
#     Unnamed: 0     Unnamed: 1      Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN            NaN             NaN         NaN         NaN
# 1          NaN         Sesión   Tiempo/Series         NaN         NaN
# 2          NaN  Calentamiento    5-10 minutos         NaN         NaN
# 3          NaN     Compuestos  3/4s -> 6-10rp         NaN         NaN
# 4          NaN    Aislamiento   3s -> 10-15rp         NaN         NaN
# 5          NaN   Descanso ser  60-90s // 120s         NaN         NaN
# 6          NaN   Estiramiento       5 minutos         NaN         NaN
# 7          NaN            NaN             NaN         NaN         NaN
# 8          NaN            NaN             NaN         NaN         NaN
# 9          NaN            NaN             NaN         NaN         NaN
# 10         NaN            NaN             NaN         NaN         NaN
# 11         NaN            NaN             NaN         NaN         NaN
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0     Unnamed: 1      Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN            NaN             NaN         NaN         NaN
# 1         NaN         Sesión   Tiempo/Series         NaN         NaN
# 2         NaN  Calentamiento    5-10 minutos         NaN         NaN
# 3         NaN     Compuestos  3/4s -> 6-10rp         NaN         NaN
# 4         NaN    Aislamiento   3s -> 10-15rp         NaN         NaN
#
#                 Unnamed: 5              Unnamed: 6  \
# 0                      NaN                     NaN
# 1          Lunes - Piernas  Martes - Pecho/Triceps
# 2         Sentadillas 4x12       Flexiones 4x10-20
# 3   Zancadas con peso 3x10    Flexiones banco 3x10
# 4  Sentadilla en silla 3x8  Flexiones diamante 3x8
#
#                     Unnamed: 7                           Unnamed: 8  \
# 0                          NaN                                  NaN
# 1  Miercoles - Espalda/Triceps                     Jueves - Piernas
# ...

# %%
dataset.tail()
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 10         NaN        NaN        NaN         NaN         NaN     Huevos
# 11         NaN        NaN        NaN         NaN         NaN      Avena
# 12         NaN        NaN        NaN         NaN         NaN       Miel
# 13         NaN        NaN        NaN         NaN         NaN    Platano
# 14         NaN        NaN        NaN         NaN         NaN   Tostadas
#
#    Unnamed: 6       Unnamed: 7    Unnamed: 8 Unnamed: 9
# 10     Griego            Pollo       Pescado        NaN
# 11      Fruta            Arroz         Arroz        NaN
# 12     Nueces            Huevo       Patatas        NaN
# 13        NaN  Tostadas tomate  Huevo cocido        NaN
# 14        NaN              NaN           NaN        NaN

# %%
ds = pd.read_json(data_path / 'data.json', orient='index')
ds.head()
# Out:
#    Number     City  Gender  Age  Income Illness
# 0       1   Dallas    Male   41   40367      No
# 1       2  Houston  Female   33   50200     Yes

# %%
widths = [1,6,5,2,7,2]
ds_fijo = pd.read_fwf(data_path / 'fijo.txt', widths=widths)
ds_fijo.head()
# Out:
#    1  Dallas  Males  41  40367.0  No
# 0  1  Dallas  Males  41  40367.0  No
# 1  1  Dallas  Males  41  40367.0  No
# 2  1  Dallas  Males  41  40367.0  No
# 3  1  Dallas  Males  41  40367.0  No
# 4  1  Dallas  Males  41  40367.0  No

# %%
## Escritura

# %%
df_to_write = dataset.head(100)
df_to_write.head()
# Out:
#    Unnamed: 0     Unnamed: 1      Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN            NaN             NaN         NaN         NaN
# 1         NaN         Sesión   Tiempo/Series         NaN         NaN
# 2         NaN  Calentamiento    5-10 minutos         NaN         NaN
# 3         NaN     Compuestos  3/4s -> 6-10rp         NaN         NaN
# 4         NaN    Aislamiento   3s -> 10-15rp         NaN         NaN
#
#                 Unnamed: 5              Unnamed: 6  \
# 0                      NaN                     NaN
# 1          Lunes - Piernas  Martes - Pecho/Triceps
# 2         Sentadillas 4x12       Flexiones 4x10-20
# 3   Zancadas con peso 3x10    Flexiones banco 3x10
# 4  Sentadilla en silla 3x8  Flexiones diamante 3x8
#
#                     Unnamed: 7                           Unnamed: 8  \
# 0                          NaN                                  NaN
# 1  Miercoles - Espalda/Triceps                     Jueves - Piernas
# ...

# %%
df_to_write.to_csv(data_path / 'df_to_write.csv', index = False, sep = '#', header = False)

# %%
df_to_write.to_json(data_path / 'df_to_write.json')

# %%
df_to_write.to_parquet(data_path / 'df_to_write.parquet', engine= 'pyarrow')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\dataScience\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\anaconda3\envs\dataScience\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# ...
